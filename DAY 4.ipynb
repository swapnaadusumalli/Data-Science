# %%
#1.How to import pandas and check the version?

import pandas as pd
print(pd.__version__)
# Out:
# 1.0.1

# %%
#2.How to create a series from a numpy array?

# importing Pandas & numpy 
import pandas as pd 
import numpy as np 
  
# numpy array 
data = np.array(['a', 'b', 'c', 'd', 'e']) 
  
# creating series 
s = pd.Series(data) 
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
#3.How to convert the index of a series into a column of a dataframe?
import pandas as pd 
import numpy as np 
series = pd.Series({'a': 1, 'b': 2, 'c': 3})
print("series is :",series)
df = pd.DataFrame(series).transpose()
print("dataframe is :",df)
# Out:
# series is : a    1
# b    2
# c    3
# dtype: int64
# dataframe is :    a  b  c
# 0  1  2  3

# %%
#4.Write the code to list all the datasets available in seaborn library.Load the 'mpg' dataset Note: mpg dataset will be read from seaborn module in the manner sir has already shown(provided in the
# materials folder)

#import seaborn as sb
print(sb.get_dataset_names())

mpg= sb.load_dataset('mpg')
mpg.head()
# Out:
# C:\Users\sadusumalli\Anaconda3\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\sadusumalli\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# ...

# %%
mpg.shape
# Out:
# (398, 9)

# %%
mpg.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
mpg['cylinders'].describe()
# Out:
# count    398.000000
# mean       5.454774
# std        1.701004
# min        3.000000
# 25%        4.000000
# 50%        4.000000
# 75%        8.000000
# max        8.000000
# Name: cylinders, dtype: float64

# %%
mpg['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
sb.distplot( mpg['acceleration'] );

# %%
sb.pairplot(mpg);

# %%
mpg.describe().columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year'],
#       dtype='object')

# %%
sb.barplot(x='model_year', y='mpg', data=mpg);

# %%
sb.barplot(x='model_year', y='cylinders', data=mpg);

# %%
sb.barplot(x='model_year', y='displacement', data=mpg);

# %%
sb.barplot(x='model_year', y='displacement', data=mpg);

# %%
sb.barplot(x='model_year', y='horsepower', data=mpg);

# %%
# barplot()
import matplotlib.pyplot as plt
sb.barplot(x='origin', y='weight', data=mpg)
plt.xticks(rotation=70);

# %%
sb.boxplot(x='origin', y='mpg', data=mpg);

# %%
sb.boxplot(x='origin', y='weight', data=mpg);

# %%
mpg['origin'].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
mpg['name'].describe()
# Out:
# count            398
# unique           305
# top       ford pinto
# freq               6
# Name: name, dtype: object

# %%
#5.Which country origin cars are a part of this dataset?
mpg['origin'].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
#6.Extract the part of the dataframe which contains cars belonging to 'usa'

mpg[(mpg['origin'] == 'usa' )]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin                       name
# 0            70    usa  chevrolet chevelle malibu
# ...
